# %%
import pandas as pd

# %%
ls
# Out:
# 01_intro.ipynb   data.ipynb       key.ipynb        transaction.csv
# Untitled.ipynb   db.sqlite3       pandas.ipynb
# customer.csv     example/         pandas.zip
# customer.xlsx    item.csv         record.csv

# %%
df = pd.read_csv('transaction.csv')

# %%
df
# Out:
#         id  customer_id             datetime
# 0        1            1  2019-03-10 03:15:17
# 1        2            2  2019-03-10 03:16:14
# 2        3            1  2019-03-10 03:17:24
# 3        4           62  2016-10-30 10:08:41
# 4        5           95  2016-10-30 10:13:03
# ...    ...          ...                  ...
# 9526  9680           33  2017-04-09 14:24:03
# 9527  9681           79  2017-04-09 14:30:09
# 9528  9682           13  2017-04-09 14:32:58
# 9529  9683           89  2017-04-09 14:57:06
# 9530  9684            4  2017-04-09 15:04:24
#
# [9531 rows x 3 columns]

# %%
df.head(10)
# Out:
#    id  customer_id             datetime
# 0   1            1  2019-03-10 03:15:17
# 1   2            2  2019-03-10 03:16:14
# 2   3            1  2019-03-10 03:17:24
# 3   4           62  2016-10-30 10:08:41
# 4   5           95  2016-10-30 10:13:03
# 5   6           65  2016-10-30 10:16:55
# 6   7           35  2016-10-30 10:19:12
# 7   8           28  2016-10-30 10:20:51
# 8   9          113  2016-10-30 10:21:59
# 9  10           66  2016-10-30 10:25:58

# %%
df.tail(10)
# Out:
#         id  customer_id             datetime
# 9521  9674           85  2017-04-09 13:04:08
# 9522  9676          109  2017-04-09 13:06:34
# 9523  9677           58  2017-04-09 13:20:23
# 9524  9678           57  2017-04-09 13:49:21
# 9525  9679           21  2017-04-09 14:08:37
# 9526  9680           33  2017-04-09 14:24:03
# 9527  9681           79  2017-04-09 14:30:09
# 9528  9682           13  2017-04-09 14:32:58
# 9529  9683           89  2017-04-09 14:57:06
# 9530  9684            4  2017-04-09 15:04:24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9531 entries, 0 to 9530
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           9531 non-null   int64
#  1   customer_id  9531 non-null   int64
#  2   datetime     9531 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 223.5+ KB

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa5378ecf50>,
# ...
#       dtype=object)

# %%
df2 = pd.read_excel('customer.xlsx')

# %%
df2.head()
# Out:
#    id firstname lastname        dob
# 0   1     David    Smith 1940-04-10
# 1   2    Claire   Taylor 1977-06-14
# 2   3    Oliver    Evans 1949-11-09
# 3   4      Jack   Davies 1949-09-15
# 4   5     James  Johnson 1974-06-11

# %%
df2[:10]
# Out:
#    id firstname lastname        dob
# 0   1     David    Smith 1940-04-10
# 1   2    Claire   Taylor 1977-06-14
# 2   3    Oliver    Evans 1949-11-09
# 3   4      Jack   Davies 1949-09-15
# 4   5     James  Johnson 1974-06-11
# 5   6     Harry    Brown 1961-08-28
# 6   7    Thomas   Wilson 1931-11-06
# 7   8    Thomas   Taylor 1944-12-16
# 8   9      Alex    Brown 1928-07-02
# 9  10   William    Evans 1943-07-30

# %%
df2[df2['id']<10]
# Out:
#    id firstname lastname        dob
# 0   1     David    Smith 1940-04-10
# 1   2    Claire   Taylor 1977-06-14
# 2   3    Oliver    Evans 1949-11-09
# 3   4      Jack   Davies 1949-09-15
# 4   5     James  Johnson 1974-06-11
# 5   6     Harry    Brown 1961-08-28
# 6   7    Thomas   Wilson 1931-11-06
# 7   8    Thomas   Taylor 1944-12-16
# 8   9      Alex    Brown 1928-07-02

# %%
df2[df2['firstname']=='Thomas']
# Out:
#       id firstname lastname        dob
# 6      7    Thomas   Wilson 1931-11-06
# 7      8    Thomas   Taylor 1944-12-16
# 28    29    Thomas   Davies 1989-08-08
# 35    36    Thomas  Johnson 1990-07-28
# 86    87    Thomas    Evans 1995-02-28
# 94    95    Thomas    Smith 1975-01-24
# 111  112    Thomas    Jones 1985-01-18
# 118  119    Thomas    Brown 1948-06-19

# %%
df2[(df2['firstname']=='Thomas') | (df2['firstname']=='Alex')]
# Out:
#       id firstname lastname        dob
# 6      7    Thomas   Wilson 1931-11-06
# 7      8    Thomas   Taylor 1944-12-16
# 8      9      Alex    Brown 1928-07-02
# 10    11      Alex    Evans 1926-07-05
# 13    14      Alex   Wilson 1933-01-01
# 20    21      Alex  Johnson 1927-02-21
# 28    29    Thomas   Davies 1989-08-08
# 35    36    Thomas  Johnson 1990-07-28
# 44    45      Alex   Davies 1997-01-29
# 58    59      Alex    Jones 1984-11-02
# 78    79      Alex    Smith 1924-06-20
# 86    87    Thomas    Evans 1995-02-28
# 87    88      Alex   Taylor 1927-07-29
# 94    95    Thomas    Smith 1975-01-24
# 111  112    Thomas    Jones 1985-01-18
# 118  119    Thomas    Brown 1948-06-19

# %%
df2[(df2['firstname']=='Alex') & (df2['id']<50)]
# Out:
#     id firstname lastname        dob
# 8    9      Alex    Brown 1928-07-02
# 10  11      Alex    Evans 1926-07-05
# 13  14      Alex   Wilson 1933-01-01
# 20  21      Alex  Johnson 1927-02-21
# 44  45      Alex   Davies 1997-01-29

# %%
df2.keys()
# Out:
# Index(['id', 'firstname', 'lastname', 'dob'], dtype='object')

# %%
df2[['firstname', 'lastname']]
# Out:
#     firstname lastname
# 0       David    Smith
# 1      Claire   Taylor
# 2      Oliver    Evans
# 3        Jack   Davies
# 4       James  Johnson
# ..        ...      ...
# 115     James    Jones
# 116     Jacob    Evans
# 117    Oliver   Taylor
# 118    Thomas    Brown
# 119     Harry   Davies
#
# [120 rows x 2 columns]

# %%
df2.drop(['id','dob'],axis=1)
# Out:
#     firstname lastname
# 0       David    Smith
# 1      Claire   Taylor
# 2      Oliver    Evans
# 3        Jack   Davies
# 4       James  Johnson
# ..        ...      ...
# 115     James    Jones
# 116     Jacob    Evans
# 117    Oliver   Taylor
# 118    Thomas    Brown
# 119     Harry   Davies
#
# [120 rows x 2 columns]

# %%
df
# Out:
#         id  customer_id             datetime
# 0        1            1  2019-03-10 03:15:17
# 1        2            2  2019-03-10 03:16:14
# 2        3            1  2019-03-10 03:17:24
# 3        4           62  2016-10-30 10:08:41
# 4        5           95  2016-10-30 10:13:03
# ...    ...          ...                  ...
# 9526  9680           33  2017-04-09 14:24:03
# 9527  9681           79  2017-04-09 14:30:09
# 9528  9682           13  2017-04-09 14:32:58
# 9529  9683           89  2017-04-09 14:57:06
# 9530  9684            4  2017-04-09 15:04:24
#
# [9531 rows x 3 columns]

# %%
df.groupby(['customer_id']).agg(['sum','mean','max','std','min'])
# Out:
#                  id
#                 sum         mean   max          std  min
# customer_id
# 1            364981  4505.938272  9542  2704.664366    1
# 2            391947  4838.851852  9559  2950.590039    2
# 3            353803  4781.121622  9303  2895.077097   35
# 4            345206  4315.075000  9684  2962.817842   83
# 5            464106  4784.597938  9478  2680.098088  236
# ...             ...          ...   ...          ...  ...
# 116          465512  5115.516484  9658  2847.646164   13
# 117          302996  4734.312500  9336  2597.631650   57
# 118          378389  4851.141026  9406  3034.242522   98
# 119          411973  4477.967391  9651  2853.080022   71
# 120          420424  5065.349398  9592  2952.315521  158
#
# [120 rows x 5 columns]

# %%
transaction = df

# %%
customer = df2

# %%
transaction.head()
# Out:
#    id  customer_id             datetime
# 0   1            1  2019-03-10 03:15:17
# 1   2            2  2019-03-10 03:16:14
# 2   3            1  2019-03-10 03:17:24
# 3   4           62  2016-10-30 10:08:41
# 4   5           95  2016-10-30 10:13:03

# %%
customer.head()
# Out:
#    id firstname lastname        dob
# 0   1     David    Smith 1940-04-10
# 1   2    Claire   Taylor 1977-06-14
# 2   3    Oliver    Evans 1949-11-09
# 3   4      Jack   Davies 1949-09-15
# 4   5     James  Johnson 1974-06-11

# %%
transaction.merge(customer,left_on='customer_id',right_on='id')
# Out:
#       id_x  customer_id             datetime  id_y firstname lastname  \
# 0        1            1  2019-03-10 03:15:17     1     David    Smith
# 1        3            1  2019-03-10 03:17:24     1     David    Smith
# 2      387            1  2016-11-03 12:16:15     1     David    Smith
# 3      542            1  2016-11-05 09:34:43     1     David    Smith
# 4      612            1  2016-11-05 13:31:32     1     David    Smith
# ...    ...          ...                  ...   ...       ...      ...
# 9526  9108           96  2017-03-31 11:16:09    96    Claire    Brown
# 9527  9173           96  2017-04-01 10:22:55    96    Claire    Brown
# 9528  9245           96  2017-04-02 10:50:11    96    Claire    Brown
# 9529  9357           96  2017-04-04 11:09:31    96    Claire    Brown
# 9530  9535           96  2017-04-07 13:46:25    96    Claire    Brown
#
#             dob
# 0    1940-04-10
# 1    1940-04-10
# 2    1940-04-10
# 3    1940-04-10
# 4    1940-04-10
# ...         ...
# ...

# %%
data = pd.merge(customer,transaction,left_on='id',right_on='customer_id')

# %%
data
# Out:
#       id_x firstname lastname        dob  id_y  customer_id  \
# 0        1     David    Smith 1940-04-10     1            1
# 1        1     David    Smith 1940-04-10     3            1
# 2        1     David    Smith 1940-04-10   387            1
# 3        1     David    Smith 1940-04-10   542            1
# 4        1     David    Smith 1940-04-10   612            1
# ...    ...       ...      ...        ...   ...          ...
# 9526   120     Harry   Davies 1959-09-07  9389          120
# 9527   120     Harry   Davies 1959-09-07  9399          120
# 9528   120     Harry   Davies 1959-09-07  9534          120
# 9529   120     Harry   Davies 1959-09-07  9581          120
# 9530   120     Harry   Davies 1959-09-07  9592          120
#
#                  datetime
# 0     2019-03-10 03:15:17
# 1     2019-03-10 03:17:24
# 2     2016-11-03 12:16:15
# 3     2016-11-05 09:34:43
# 4     2016-11-05 13:31:32
# ...                   ...
# 9526  2017-04-04 15:47:40
# ...

# %%
for i,data in transaction.iterrows():
    print(i,data)
# Out:
# 0 id                               1
# customer_id                      1
# datetime       2019-03-10 03:15:17
# Name: 0, dtype: object
# 1 id                               2
# customer_id                      2
# datetime       2019-03-10 03:16:14
# Name: 1, dtype: object
# 2 id                               3
# customer_id                      1
# datetime       2019-03-10 03:17:24
# Name: 2, dtype: object
# 3 id                               4
# customer_id                     62
# datetime       2016-10-30 10:08:41
# Name: 3, dtype: object
# 4 id                               5
# customer_id                     95
# datetime       2016-10-30 10:13:03
# Name: 4, dtype: object
# 5 id                               6
# customer_id                     65
# datetime       2016-10-30 10:16:55
# Name: 5, dtype: object
# 6 id                               7
# customer_id                     35
# datetime       2016-10-30 10:19:12
# Name: 6, dtype: object
# ...
