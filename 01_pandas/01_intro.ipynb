# %%
import pandas as pd

# %%
df = pd.read_csv('transaction.csv')

# %%
df
# Out:
#         id  customer_id             datetime
# 0        1            1  2019-03-10 03:15:17
# 1        2            2  2019-03-10 03:16:14
# 2        3            1  2019-03-10 03:17:24
# 3        4           62  2016-10-30 10:08:41
# 4        5           95  2016-10-30 10:13:03
# ...    ...          ...                  ...
# 9526  9680           33  2017-04-09 14:24:03
# 9527  9681           79  2017-04-09 14:30:09
# 9528  9682           13  2017-04-09 14:32:58
# 9529  9683           89  2017-04-09 14:57:06
# 9530  9684            4  2017-04-09 15:04:24
#
# [9531 rows x 3 columns]

# %%
df.head()
# Out:
#    id  customer_id             datetime
# 0   1            1  2019-03-10 03:15:17
# 1   2            2  2019-03-10 03:16:14
# 2   3            1  2019-03-10 03:17:24
# 3   4           62  2016-10-30 10:08:41
# 4   5           95  2016-10-30 10:13:03

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9531 entries, 0 to 9530
# Data columns (total 3 columns):
# id             9531 non-null int64
# customer_id    9531 non-null int64
# datetime       9531 non-null object
# dtypes: int64(2), object(1)
# memory usage: 223.5+ KB

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdbb7ffd710>,
# ...
#       dtype=object)

# %%
df[:10]
# Out:
#    id  customer_id             datetime
# 0   1            1  2019-03-10 03:15:17
# 1   2            2  2019-03-10 03:16:14
# 2   3            1  2019-03-10 03:17:24
# 3   4           62  2016-10-30 10:08:41
# 4   5           95  2016-10-30 10:13:03
# 5   6           65  2016-10-30 10:16:55
# 6   7           35  2016-10-30 10:19:12
# 7   8           28  2016-10-30 10:20:51
# 8   9          113  2016-10-30 10:21:59
# 9  10           66  2016-10-30 10:25:58

# %%
df[df['id']<10]
# Out:
#    id  customer_id             datetime
# 0   1            1  2019-03-10 03:15:17
# 1   2            2  2019-03-10 03:16:14
# 2   3            1  2019-03-10 03:17:24
# 3   4           62  2016-10-30 10:08:41
# 4   5           95  2016-10-30 10:13:03
# 5   6           65  2016-10-30 10:16:55
# 6   7           35  2016-10-30 10:19:12
# 7   8           28  2016-10-30 10:20:51
# 8   9          113  2016-10-30 10:21:59

# %%
df[['id','customer_id']]
# Out:
#         id  customer_id
# 0        1            1
# 1        2            2
# 2        3            1
# 3        4           62
# 4        5           95
# ...    ...          ...
# 9526  9680           33
# 9527  9681           79
# 9528  9682           13
# 9529  9683           89
# 9530  9684            4
#
# [9531 rows x 2 columns]

# %%
df[(df['id']<100) & (df['customer_id']<10)]
# Out:
#     id  customer_id             datetime
# 0    1            1  2019-03-10 03:15:17
# 1    2            2  2019-03-10 03:16:14
# 2    3            1  2019-03-10 03:17:24
# 19  20            2  2016-10-30 10:45:22
# 34  35            3  2016-10-30 11:27:34
# 39  40            2  2016-10-30 11:55:51
# 43  44            2  2016-10-30 12:05:47
# 54  56            9  2016-10-30 12:39:27
# 56  58            2  2016-10-30 12:59:29
# 61  63            2  2016-10-30 13:33:12
# 81  83            4  2016-10-31 08:57:47

# %%
df[(df['id']==100) | (df['id']<20)]
# Out:
#      id  customer_id             datetime
# 0     1            1  2019-03-10 03:15:17
# 1     2            2  2019-03-10 03:16:14
# 2     3            1  2019-03-10 03:17:24
# 3     4           62  2016-10-30 10:08:41
# 4     5           95  2016-10-30 10:13:03
# 5     6           65  2016-10-30 10:16:55
# 6     7           35  2016-10-30 10:19:12
# 7     8           28  2016-10-30 10:20:51
# 8     9          113  2016-10-30 10:21:59
# 9    10           66  2016-10-30 10:25:58
# 10   11           84  2016-10-30 10:27:21
# 11   12           19  2016-10-30 10:30:14
# 12   13          116  2016-10-30 10:31:24
# 13   14           70  2016-10-30 10:32:46
# 14   15           18  2016-10-30 10:34:36
# 15   16           79  2016-10-30 10:37:08
# 16   17           17  2016-10-30 10:38:04
# 17   18           17  2016-10-30 10:41:56
# 18   19           27  2016-10-30 10:43:08
# 98  100           81  2016-10-31 09:58:06

# %%
for i,data in df.iterrows():
    print(i, data)
    break
# Out:
# 0 id                               1
# customer_id                      1
# datetime       2019-03-10 03:15:17
# Name: 0, dtype: object

# %%
df.groupby('customer_id').agg(['count','mean','max','min','std'])
# Out:
#                id
#             count         mean   max  min          std
# customer_id
# 1              81  4505.938272  9542    1  2704.664366
# 2              81  4838.851852  9559    2  2950.590039
# 3              74  4781.121622  9303   35  2895.077097
# 4              80  4315.075000  9684   83  2962.817842
# 5              97  4784.597938  9478  236  2680.098088
# ...           ...          ...   ...  ...          ...
# 116            91  5115.516484  9658   13  2847.646164
# 117            64  4734.312500  9336   57  2597.631650
# 118            78  4851.141026  9406   98  3034.242522
# 119            92  4477.967391  9651   71  2853.080022
# 120            83  5065.349398  9592  158  2952.315521
#
# [120 rows x 5 columns]

# %%
df_transaction = pd.read_csv('transaction.csv')
df_transaction.head()
# Out:
#    id  customer_id             datetime
# 0   1            1  2019-03-10 03:15:17
# 1   2            2  2019-03-10 03:16:14
# 2   3            1  2019-03-10 03:17:24
# 3   4           62  2016-10-30 10:08:41
# 4   5           95  2016-10-30 10:13:03

# %%
df_customer = pd.read_csv('customer.csv')
df_customer.head()
# Out:
#    id firstname lastname         dob
# 0   1     David    Smith  1940-04-10
# 1   2    Claire   Taylor  1977-06-14
# 2   3    Oliver    Evans  1949-11-09
# 3   4      Jack   Davies  1949-09-15
# 4   5     James  Johnson  1974-06-11

# %%
df = pd.merge(df_customer,df_transaction,left_on='id',right_on='customer_id')
df
# Out:
#       id_x firstname lastname         dob  id_y  customer_id  \
# 0        1     David    Smith  1940-04-10     1            1
# 1        1     David    Smith  1940-04-10     3            1
# 2        1     David    Smith  1940-04-10   387            1
# 3        1     David    Smith  1940-04-10   542            1
# 4        1     David    Smith  1940-04-10   612            1
# ...    ...       ...      ...         ...   ...          ...
# 9526   120     Harry   Davies  1959-09-07  9389          120
# 9527   120     Harry   Davies  1959-09-07  9399          120
# 9528   120     Harry   Davies  1959-09-07  9534          120
# 9529   120     Harry   Davies  1959-09-07  9581          120
# 9530   120     Harry   Davies  1959-09-07  9592          120
#
#                  datetime
# 0     2019-03-10 03:15:17
# 1     2019-03-10 03:17:24
# 2     2016-11-03 12:16:15
# 3     2016-11-05 09:34:43
# 4     2016-11-05 13:31:32
# ...                   ...
# 9526  2017-04-04 15:47:40
# ...

# %%
df.drop(['id_y','id_x'],axis=1)
# Out:
#      firstname lastname         dob  customer_id             datetime
# 0        David    Smith  1940-04-10            1  2019-03-10 03:15:17
# 1        David    Smith  1940-04-10            1  2019-03-10 03:17:24
# 2        David    Smith  1940-04-10            1  2016-11-03 12:16:15
# 3        David    Smith  1940-04-10            1  2016-11-05 09:34:43
# 4        David    Smith  1940-04-10            1  2016-11-05 13:31:32
# ...        ...      ...         ...          ...                  ...
# 9526     Harry   Davies  1959-09-07          120  2017-04-04 15:47:40
# 9527     Harry   Davies  1959-09-07          120  2017-04-05 09:35:36
# 9528     Harry   Davies  1959-09-07          120  2017-04-07 13:45:41
# 9529     Harry   Davies  1959-09-07          120  2017-04-08 10:50:13
# 9530     Harry   Davies  1959-09-07          120  2017-04-08 12:10:49
#
# [9531 rows x 5 columns]

# %%
df_customer.merge(df_transaction,left_on='id',right_on='customer_id')
# Out:
#       id_x firstname lastname         dob  id_y  customer_id  \
# 0        1     David    Smith  1940-04-10     1            1
# 1        1     David    Smith  1940-04-10     3            1
# 2        1     David    Smith  1940-04-10   387            1
# 3        1     David    Smith  1940-04-10   542            1
# 4        1     David    Smith  1940-04-10   612            1
# ...    ...       ...      ...         ...   ...          ...
# 9526   120     Harry   Davies  1959-09-07  9389          120
# 9527   120     Harry   Davies  1959-09-07  9399          120
# 9528   120     Harry   Davies  1959-09-07  9534          120
# 9529   120     Harry   Davies  1959-09-07  9581          120
# 9530   120     Harry   Davies  1959-09-07  9592          120
#
#                  datetime
# 0     2019-03-10 03:15:17
# 1     2019-03-10 03:17:24
# 2     2016-11-03 12:16:15
# 3     2016-11-05 09:34:43
# 4     2016-11-05 13:31:32
# ...                   ...
# 9526  2017-04-04 15:47:40
# ...
